# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.3/901.3 kB 44.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("ok")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ok

# %%
# !unzip "Peruvian plate detection.v2i.yolov11.zip" -d /content/
# Out:
# Archive:  Peruvian plate detection.v2i.yolov11.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/IMG-117402_png.rf.8a60e760bcc8fba74ae40b733b06278f.jpg
#  extracting: /content/test/images/IMG-118887_png.rf.dedf3407d380d39616b56643c07114e1.jpg
#  extracting: /content/test/images/IMG-19678_png.rf.f189d5ce1537ca94ff81cbb8ce60454c.jpg
#  extracting: /content/test/images/IMG-22263_png.rf.06b3c435891d633e810ff32d8a3a9398.jpg
#  extracting: /content/test/images/IMG-23528_png.rf.248abeb8da5a7b3c7c97950ad98c1fa3.jpg
#  extracting: /content/test/images/IMG-2738_png.rf.fb11cbee12df4d17907f26c4cfa57db4.jpg
#  extracting: /content/test/images/IMG-27565_png.rf.02b174aeecf18a9485634e967ce41b24.jpg
#  extracting: /content/test/images/IMG-27840_png.rf.e02a6238162af5bd2a56c9c408ea02e1.jpg
# ...

# %%
# !yolo detect train data='/content/data.yaml' model='yolo11n.pt' epochs=100 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 406MB/s]
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt source="/content/test/images/img-32229_png.rf.e9c1cad13b7e43c264aec28fd675bc5a.jpg" imgsz=640
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/img-32229_png.rf.e9c1cad13b7e43c264aec28fd675bc5a.jpg: 640x640 1 car-plate, 12.3ms
# Speed: 2.6ms preprocess, 12.3ms inference, 585.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display

result_image_path = 'runs/detect/predict/img-32229_png.rf.e9c1cad13b7e43c264aec28fd675bc5a.jpg'

display(Image(filename=result_image_path))

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt source="/content/test/images/yaris.jpeg" imgsz=640
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/yaris.jpeg: 384x640 1 car-plate, 54.7ms
# Speed: 2.6ms preprocess, 54.7ms inference, 737.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls runs/detect/predict6
# Out:
# yaris.jpg

# %%
from IPython.display import Image, display

result_image_path = "runs/detect/predict6/yaris.jpg"
display(Image(filename=result_image_path))

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt source="/content/test/images/honda.jpeg" imgsz=640
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/honda.jpeg: 256x640 3 car-plates, 93.6ms
# Speed: 2.5ms preprocess, 93.6ms inference, 590.7ms postprocess per image at shape (1, 3, 256, 640)
# Results saved to runs/detect/predict9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls runs/detect/predict9
# Out:
# honda.jpg

# %%
from IPython.display import Image, display

result_image_path = "runs/detect/predict9/honda.jpg"
display(Image(filename=result_image_path))

# %%
# !yolo task=detect mode=predict model=./runs/detect/train/weights/best.pt source="/content/test/images/guapo.jpeg" imgsz=640
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/guapo.jpeg: 640x640 1 car-plate, 11.6ms
# Speed: 5.5ms preprocess, 11.6ms inference, 567.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls runs/detect/predict10
# Out:
# guapo.jpg

# %%
from IPython.display import Image, display

result_image_path = "runs/detect/predict10/guapo.jpg"
display(Image(filename=result_image_path))
